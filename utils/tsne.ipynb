# %%
import numpy as np

# %%
ai=np.load('/data/pxg1/CLIP1/npz_data/arrays_ai.npz')
wild=np.load('/data/pxg1/CLIP1/npz_data/arrays_wild.npz')

# %%
# b=np.mean(a['l23'], axis=1)
ai_23=ai['l23'].reshape(120, -1)
wild_23=wild['l23'].reshape(120, -1)

# %%
ai_23_=tsne.fit_transform(ai_23)
wild_23_=tsne.fit_transform(wild_23)

# %%
plt.scatter(ai_23_[:,0],ai_23_[:,1])
plt.scatter(wild_23_[:,0],wild_23_[:,1])
plt.show()

# %%
ai_22=ai['l22'].reshape(120, -1)
wild_22=wild['l22'].reshape(120, -1)

# %%
ai_22_=tsne.fit_transform(ai_22)
wild_22_=tsne.fit_transform(wild_22)

# %%
plt.scatter(ai_22_[:,0],ai_22_[:,1])
plt.scatter(wild_22_[:,0],wild_22_[:,1])
plt.show()

# %%
ai_21=ai['l21'].reshape(120, -1)
wild_21=wild['l21'].reshape(120, -1)

# %%
ai_21_=tsne.fit_transform(ai_21)
wild_21_=tsne.fit_transform(wild_21)

# %%
plt.scatter(ai_21_[:,0],ai_21_[:,1])
plt.scatter(wild_21_[:,0],wild_21_[:,1])
plt.show()

# %%
ai_21=ai['l20'].reshape(120, -1)
wild_21=wild['l20'].reshape(120, -1)
ai_21_=tsne.fit_transform(ai_21)
wild_21_=tsne.fit_transform(wild_21)
plt.scatter(ai_21_[:,0],ai_21_[:,1])
plt.scatter(wild_21_[:,0],wild_21_[:,1])
plt.show()

# %%
ai_21=ai['l19'].reshape(120, -1)
wild_21=wild['l19'].reshape(120, -1)
ai_21_=tsne.fit_transform(ai_21)
wild_21_=tsne.fit_transform(wild_21)
plt.scatter(ai_21_[:,0],ai_21_[:,1])
plt.scatter(wild_21_[:,0],wild_21_[:,1])
plt.show()
